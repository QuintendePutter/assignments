# %% [markdown]
# # Exam
#
# In this exam, we will work with the "frequently requested health data” from the OECD.
# Your task is to compute a simple “efficiency score” and make three plots.
#
#
# You will earn a higher grade if you provide nicer graphs.

# %% [markdown]
# Quinten de Putter
#
# SNR: 2004394

# %% [markdown]
# Now you need to call the libaries
#
# * ggplot2
# * dplyr

# %%
library(ggplot2)
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# Now you have to read the de data that we have cleaned during tutorial 3. The csv file is called oecddata.csv

# %%
oecd <-read.csv("oecddata.csv", sep=";")

# %% [markdown]
# To see how the data look like, use the command:
#
# head(oecd)
#
# With the command
#
# oecd
#
#
# You can see the dataset in total.

# %%
head(oecd)
# Out:
#   X Country   Year Cost      LE
# 1 1 Australia 2005 2842,1321 80,9
# 2 2 Australia 2006 3023,0978 81,1
# 3 3 Australia 2007 3196,226  81,4
# 4 4 Australia 2008 3310,1708 81,5
# 5 5 Australia 2009 3564,4049 81,6
# 6 6 Australia 2010 3607,3407 81,8

# %%
oecd
# Out:
#     X   Country        Year Cost      LE
# 1    1  Australia      2005 2842,1321 80,9
# 2    2  Australia      2006 3023,0978 81,1
# 3    3  Australia      2007 3196,226  81,4
# 4    4  Australia      2008 3310,1708 81,5
# 5    5  Australia      2009 3564,4049 81,6
# 6    6  Australia      2010 3607,3407 81,8
# 7    7  Australia      2011 3794,0874 82
# 8    8  Australia      2012 3807,6819 82,1
# 9    9  Australia      2013 4176,853  82,2
# 10  10  Australia      2014 4206,8516 82,4
# 11  11  Australia      2015 4420,4364 NA
# 12  12  Austria        2005 3324,0795 79,4
# 13  13  Austria        2006 3567,6495 80
# 14  14  Austria        2007 3718,739  80,3
# 15  15  Austria        2008 3964,8495 80,5
# 16  16  Austria        2009 4119,7452 80,4
# 17  17  Austria        2010 4236,3164 80,7
# 18  18  Austria        2011 4362,3426 81,1
# 19  19  Austria        2012 4646,4365 81
# 20  20  Austria        2013 4806,3934 81,2
# 21  21  Austria        2014 4895,9992 81,6
# ...

# %% [markdown]
# ## Graphs

# %% [markdown]
# To make the graphs we need to make selections of the data. Please use "dplyr" (commands "select" and "filter") and the "pipe". The first assignment is to make a scatterplot using "ggplot". The graph contains data for all countries for the year 2014. Therefore make a dataframe with dplyr first, called "graph1" with the required data.
# Then, make a scatterplot with "Cost" on the x-axis and "LE" on the y-axis. You have to add a regression line with a shaded area for the confidence interval.

# %%
graph1 <- data.frame(oecd) %>%
    select(Country, Year, Cost, LE) %>%
    filter(Year == 2014)
graph1
# Out:
#    Country         Year Cost      LE
# 1  Australia       2014 4206,8516 82,4
# 2  Austria         2014 4895,9992 81,6
# 3  Belgium         2014 4522,045  81,4
# 4  Canada          2014 4491,7648 NA
# 5  Chile           2014 1688,5233 79
# 6  Czech Republic  2014 2386,3385 78,9
# 7  Denmark         2014 4857,0285 80,8
# 8  Estonia         2014 1724,51   77,2
# 9  Finland         2014 3870,4    81,3
# 10 France          2014 4366,9864 82,8
# 11 Germany         2014 5119,2146 81,2
# 12 Greece          2014 2220,1065 81,5
# 13 Hungary         2014 1796,6034 75,9
# 14 Iceland         2014 3896,9251 82,9
# 15 Ireland         2014 5001,322  81,4
# 16 Israel          2014 2547,401  82,2
# 17 Italy           2014 3206,8286 83,2
# 18 Japan           2014 4152,3727 83,7
# 19 Korea           2014 2361,44   82,2
# 20 Latvia          2014 1295,0128 74,3
# 21 Luxembourg      2014 6682,237  82,3
# 22 Mexico          2014 1035,3389 74,8
# 23 Netherlands     2014 5276,6003 81,8
# ...

# %%
ggplot(graph1, aes(x = Cost, y = LE))+ geom_point() + geom_smooth(method=lm)
# Out:
# plot without title

# %% [markdown]
# **explanation**
#
# The graph1 function seems to be alright here. However my graph is not working properly. Using the Geom_smooth should give a regression line as in the lectures, however it is not working which is a shame. Points seem to be in the correct place, however the cost-axile is not proper with to much numbers.

# %% [markdown]
# The second assignment is to make a line graph. You will use the years 2005-2015 for 5 countries (you can choose your own countries). Make a new dataframe called graph2 with the required data. Then, make a line graph with "Year"  and "Cost" on the y-axis. There should be coloured lines per country and a legend attached.

# %%
graph2 <- data.frame(oecd) %>%
    select(Country, Year, Cost) %>%
    filter(Country %in% c("Sweden", "Switzerland", "Turkey", "United Kingdom", "Slovak Republic"))
graph2
# Out:
#    Country         Year Cost
# 1  Slovak Republic 2005 1093,9081
# 2  Slovak Republic 2006 1294,5212
# 3  Slovak Republic 2007 1545,5981
# 4  Slovak Republic 2008 1665,2449
# 5  Slovak Republic 2009 1849,6847
# 6  Slovak Republic 2010 1917,8972
# 7  Slovak Republic 2011 1871,8732
# 8  Slovak Republic 2012 1999,5644
# 9  Slovak Republic 2013 2073,0478
# 10 Slovak Republic 2014 1970,523
# 11 Slovak Republic 2015 2063,7541
# 12 Sweden          2005 2841,8221
# 13 Sweden          2006 3066,2039
# 14 Sweden          2007 3274,849
# 15 Sweden          2008 3481,5901
# 16 Sweden          2009 3547,1337
# 17 Sweden          2010 3543,5822
# 18 Sweden          2011 4667,6964
# 19 Sweden          2012 4860,2524
# 20 Sweden          2013 5003,1323
# 21 Sweden          2014 5065,1613
# 22 Sweden          2015 5227,8349
# 23 Switzerland     2005 4015,3331
# 24 Switzerland     2006 4251,3673
# 25 Switzerland     2007 4567,3285
# 26 Switzerland     2008 4933,1
# 27 Switzerland     2009 5183,952
# ...

# %%
graph2$Country <- as.factor(graph2$Country)
ggplot(graph2, aes(x = Year, y = Cost, col = Country))+ geom_line()
# Out:
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
# plot without title

# %% [markdown]
# **explanation**
#
# Well here I have the same issue as above which is a bit annoying. The Y- axile (Cost again) is way to big to get those lines. Table seems to be alright...

# %% [markdown]
# ## Efficiency scores
#
# The last assignment is to compute simple effiency scores. We will use the year 2014 for all countries (i.e. the dataframe "graph1").
# Make a new dateframe called "eff" (using graph1). Please use the "pipe" to execute to following steps:
# Select all the variables except the NA's (hint: use na.omit) and create a new column called "Ratio" with mutate. Ratio is defined as "Cost/LE" (cost per output).
# Create a new column called "Score" with mutate. Score is the ratio per country divided by the lowest ratio in the dataframe.
# To complete this dataframe order the dataset using "arrange" based on score (i.e. lowest Score first).
#
#
# Finally make a bar chart using ggplot. Countries should be on the x-axis and "Score" on the y-axis.
#
#
#
# You can earn extra points if you are able to order the graph based on scores (lowest first, highest last), if you are able to make the x-axis readable, make the bar of the Netherlands red and the other bars blue and/or change the name of the y-axis to "Efficiency scores according to [your name]"
#
#
# The figure should like this:
#
# ![My Figure](eff.png)

# %%
eff <- graph1 %>%
    mutate(Ratio = Cost / LE) %>%
    mutate(Score = min(Ratio) / Ratio) %>%
    arrange(Score)
eff
# Out:
# Warning message in Ops.factor(structure(c(264L, 306L, 288L, 284L, 54L, 106L, 303L, :
# “‘/’ not meaningful for factors”
#    Country         Year Cost      LE   Ratio Score
# 1  Australia       2014 4206,8516 82,4 NA    NA
# 2  Austria         2014 4895,9992 81,6 NA    NA
# 3  Belgium         2014 4522,045  81,4 NA    NA
# 4  Canada          2014 4491,7648 NA   NA    NA
# 5  Chile           2014 1688,5233 79   NA    NA
# 6  Czech Republic  2014 2386,3385 78,9 NA    NA
# 7  Denmark         2014 4857,0285 80,8 NA    NA
# 8  Estonia         2014 1724,51   77,2 NA    NA
# 9  Finland         2014 3870,4    81,3 NA    NA
# 10 France          2014 4366,9864 82,8 NA    NA
# 11 Germany         2014 5119,2146 81,2 NA    NA
# 12 Greece          2014 2220,1065 81,5 NA    NA
# 13 Hungary         2014 1796,6034 75,9 NA    NA
# 14 Iceland         2014 3896,9251 82,9 NA    NA
# 15 Ireland         2014 5001,322  81,4 NA    NA
# 16 Israel          2014 2547,401  82,2 NA    NA
# ...

# %%
ggplot(eff, aes(x = reorder(Country,Score), y = Score, fill= Country)) + 
    guides(fill=FALSE) +
    geom_bar(stat = "identity") +
    xlab("Country") +
    ylab("Efficiency scores according to Quinten") +

    theme(axis.text.x = element_text(angle = 50, hjust = 1))
# Out:
# Warning message:
# “Removed 35 rows containing missing values (position_stack).”
# plot without title

# %% [markdown]
# So Something went wrong here as well i could say.. The ratio and score function are not working, so the graph is also not working. First the names of the countries were going through each other so it was not clear which country stood were. With the last line is was able to solve that. It's only disappointing that the Ratio and Score are just not working. Maybe missed a download or something? i have no idea. Also started too late to raise the issue on github.
